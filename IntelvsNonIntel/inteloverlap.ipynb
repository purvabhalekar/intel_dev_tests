# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("white")
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap 
import statistics

# %%
cmap = ListedColormap(sns.color_palette("mako_r", 256).as_hex())
markers = {"intel": "s", "non intel": "X"}

# %%
f1 = pd.read_fwf('depth_intel.txt')
f1["Type"] = "intel"
f2 = pd.read_fwf('depth_nonintel.txt')
f2["Type"] = "non intel"

# %%
f = pd.concat([f1,f2], sort=True)

# %%
sns.scatterplot(data=f, x="Depth", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Depth", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
f1 = pd.read_fwf('features_intel.txt')
f1["Type"] = "intel"
f2 = pd.read_fwf('features_nonintel.txt')
f2["Type"] = "non intel"

# %%
f = pd.concat([f1,f2], sort=True)

# %%
sns.scatterplot(data=f, x="MaxFeatures", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="MaxFeatures", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
f1 = pd.read_fwf('samples_intel.txt')
f1["Type"] = "intel"
f2 = pd.read_fwf('samples_nonintel.txt')
f2["Type"] = "non intel"

# %%
f = pd.concat([f1,f2], sort=True)

# %%
sns.scatterplot(data=f, x="Samples", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Samples", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
f1 = pd.read_fwf('samples_features_intel.txt')
f1["Type"] = "intel"
f2 = pd.read_fwf('samples_features_nonintel.txt')
f2["Type"] = "non intel"

# %%
f = pd.concat([f1,f2], sort=True)

# %%
sns.scatterplot(data=f, x="Samples", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Samples", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
sns.scatterplot(data=f, x="Features", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Features", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
f1 = pd.read_fwf('samples_depth_intel.txt')
f1["Type"] = "intel"
f2 = pd.read_fwf('samples_depth_nonintel.txt')
f2["Type"] = "non intel"

# %%
f = pd.concat([f1,f2], sort=True)

# %%
sns.scatterplot(data=f, x="Samples", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Samples", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
sns.scatterplot(data=f, x="Depth", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Depth", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
f1 = pd.read_fwf('features_depth_intel.txt')
f1["Type"] = "intel"
f2 = pd.read_fwf('features_depth_nonintel.txt')
f2["Type"] = "non intel"

# %%
f = pd.concat([f1,f2], sort=True)

# %%
sns.scatterplot(data=f, x="Depth", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Depth", y="Training Time", style="Type", hue="Accuracy", markers=markers)

# %%
sns.scatterplot(data=f, x="Features", y="Accuracy", style="Type", hue="Training Time", markers=markers)

# %%
sns.scatterplot(data=f, x="Features", y="Training Time", style="Type", hue="Accuracy", markers=markers)
