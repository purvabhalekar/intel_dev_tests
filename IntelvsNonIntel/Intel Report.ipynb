# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits import mplot3d

# %%
f = pd.read_fwf('depth_intel.txt')
f.to_csv('depth_intel.csv')

# %%
plt.scatter(f['Depth'], f['Training Time'], c=f['Accuracy'])
plt.colorbar()
plt.xlabel("Depth")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying max depth from 1-196 in steps of 15 using intel libraries
#
# x-axis : Depth (1-112)
#
# y-axis : Training time

# %%
plt.scatter(f['Depth'], f['Accuracy'], c=f['Training Time'])
plt.colorbar()
plt.xlabel("Depth")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying max depth from 1-196 in steps of 15 using intel libraries
#
# x-axis : Depth (1-112)
#
# y-axis : Accuracy

# %%
f = pd.read_fwf('features_intel.txt')
f.to_csv('features_intel.csv')

# %%
f = f.drop(["Unnamed: 0", "Test", "Max" ], axis = 1)

# %%
plt.scatter(f['Features'], f['Training Time'], c=f['Accuracy'])
plt.colorbar()
plt.xlabel("Max Features")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying max features from 1-196 in steps of 15 using intel libraries
#
# x-axis : Max Features
#
# y-axis : Training time

# %%
plt.scatter(f['Features'], f['Accuracy'], c=f['Training Time'])
plt.colorbar()
plt.xlabel("Max Features")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Varying max features from 1-196 in steps of 15 using intel libraries
#
# x-axis : Max Features
#
# y-axis : Accuracy

# %%
f = pd.read_fwf('samples_intel.txt')
f.to_csv('samples_intel.csv')

# %%
plt.scatter(f['Samples'], f['Training Time'], c=f['Accuracy'])
plt.colorbar()
plt.xlabel("Samples")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying number of samples from 250000-5000000 in steps of 500000 using intel libraries
#
# x-axis : Samples
#
# y-axis : Training time

# %%
plt.scatter(f['Samples'], f['Accuracy'], c=f['Training Time'])
plt.colorbar()
plt.xlabel("Samples")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Varying number of samples from 250000-5000000 in steps of 500000 using intel libraries
#
# x-axis : Samples
#
# y-axis : Accuracy

# %%
f = pd.read_fwf('depth_nonintel.txt')
f.to_csv('depth_nonintel.csv')

# %%
plt.scatter(f['Depth'], f['Training Time'], c=f['Accuracy'])
plt.colorbar()
plt.xlabel("Depth")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying max depth from 1-196 in steps of 15 using nonintel libraries
#
# x-axis : Depth (1-112)
#
# y-axis : Training time

# %%
plt.scatter(f['Depth'], f['Accuracy'], c=f['Training Time'])
plt.colorbar()
plt.xlabel("Depth")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying max depth from 1-196 in steps of 15 using nonintel libraries
#
# x-axis : Depth (1-112)
#
# y-axis : Accuracy

# %%
f = pd.read_fwf('features_nonintel.txt')
f.to_csv('features_nonintel.csv')

# %%
plt.scatter(f['MaxFeatures'], f['Training Time'], c=f['Accuracy'])
plt.colorbar()
plt.xlabel("Max Features")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying max features from 1-196 in steps of 15 using nonintel libraries
#
# x-axis : Max Features
#
# y-axis : Training time

# %%
plt.scatter(f['MaxFeatures'], f['Accuracy'], c=f['Training Time'])
plt.colorbar()
plt.xlabel("Max Features")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Varying max features from 1-196 in steps of 15 using nonintel libraries
#
# x-axis : Max Features
#
# y-axis : Accuracy

# %%
f = pd.read_fwf('samples_nonintel.txt')
f.to_csv('samples_nonintel.csv')

# %%
plt.scatter(f['Samples'], f['Training Time'], c=f['Accuracy'])
plt.colorbar()
plt.xlabel("Samples")
plt.ylabel("Training Time")
# Out:
# Text(0, 0.5, 'Training Time')

# %% [markdown]
# Varying number of samples from 250000-5000000 in steps of 500000 using nonintel libraries
#
# x-axis : Samples
#
# y-axis : Training time

# %%
plt.scatter(f['Samples'], f['Accuracy'], c=f['Training Time'])
plt.colorbar()
plt.xlabel("Samples")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Varying number of samples from 250000-5000000 in steps of 500000 using nonintel libraries
#
# x-axis : Samples
#
# y-axis : Accuracy
