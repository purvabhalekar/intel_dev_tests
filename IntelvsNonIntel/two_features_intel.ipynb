# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap 
import statistics

# %%
f = pd.read_fwf('samples_features_nonintel.txt')
f.to_csv('samples_features_nonintel.csv')
f = f.drop(["Unnamed: 0", "Test", "Max"], axis = 1)

# %%
x = f['Features']
y = f['Samples']
z = f['Accuracy']
t = f['Training Time']
print("Accuracy :", statistics.mean(z))
print("Training Time :", statistics.mean(t))
# Out:
# Accuracy : 0.8290305478792502
# Training Time : 432.14316743656195

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=f['Training Time'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Features')
ax.set_ylabel('Samples')
ax.set_zlabel('Accuracy')

# legend
#plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.colorbar(sc)

# %%
points = plt.scatter(x, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(y, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(x, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
points = plt.scatter(y, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
f = pd.read_fwf('samples_features_intel.txt')
f.to_csv('samples_features_intel.csv')
f = f.drop(["Unnamed: 0", "Max", "Test"], axis = 1)

# %%
x = f['Features']
y = f['Samples']
z = f['Accuracy']
t = f['Training Time']
print("Accuracy :", statistics.mean(z))
print("Training Time :", statistics.mean(t))
# Out:
# Accuracy : 0.8265366735494654
# Training Time : 460.15660506378697

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=f['Training Time'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Features')
ax.set_ylabel('Samples')
ax.set_zlabel('Accuracy')

# legend
#plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.colorbar(sc)

# %%
points = plt.scatter(x, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(y, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(x, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
points = plt.scatter(y, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
f = pd.read_fwf('features_depth_intel.txt')
f.to_csv('features_depth_intel.csv')
f = f.drop(["Unnamed: 0", "Test", "Max"], axis = 1)

# %%
x = f['Depth']
y = f['Features']
z = f['Accuracy']
t = f['Training Time']
print("Accuracy :", statistics.mean(z))
print("Training Time :", statistics.mean(t))
# Out:
# Accuracy : 0.770434460530242
# Training Time : 765.544459625124

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=f['Training Time'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Depth')
ax.set_ylabel('Features')
ax.set_zlabel('Accuracy')

# legend
#plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.colorbar(sc)

# %%
points = plt.scatter(x, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(y, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(x, t,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
points = plt.scatter(y, t,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
f = pd.read_fwf('features_depth_nonintel.txt')
f.to_csv('features_depth_nonintel.csv')
f = f.drop(["Unnamed: 0", "Test", "Max"], axis = 1)

# %%
x = f['Depth']
y = f['Features']
z = f['Accuracy']
t = f['Training Time']
print("Accuracy :", statistics.mean(z))
print("Training Time :", statistics.mean(t))
# Out:
# Accuracy : 0.7588867653893937
# Training Time : 764.930303301476

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=f['Training Time'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Depth')
ax.set_ylabel('Features')
ax.set_zlabel('Accuracy')

# legend
#plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.colorbar(sc)

# %%
points = plt.scatter(x, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(y, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(x, t,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
points = plt.scatter(y, t,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Features') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
f = pd.read_fwf('samples_depth_intel.txt')
f.to_csv('samples_depth_intel.csv')
f = f.drop(["Unnamed: 0", "Test", "Max"], axis = 1)

# %%
x = f['Depth']
y = f['Samples']
z = f['Accuracy']
t = f['Training Time']
print("Accuracy :", statistics.mean(z))
print("Training Time :", statistics.mean(t))
# Out:
# Accuracy : 0.8490274523419249
# Training Time : 801.0763823581458

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=f['Training Time'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Depth')
ax.set_ylabel('Samples')
ax.set_zlabel('Accuracy')

# legend
#plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.colorbar(sc)

# %%
points = plt.scatter(x, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(y, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(x, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
points = plt.scatter(y, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
f = pd.read_fwf('samples_depth_nonintel.txt')
f.to_csv('samples_depth_nonintel.csv')
f = f.drop(["Unnamed: 0", "Test", "Max"], axis = 1)

# %%
x = f['Depth']
y = f['Samples']
z = f['Accuracy']
t = f['Training Time']
print("Accuracy :", statistics.mean(z))
print("Training Time :", statistics.mean(t))
# Out:
# Accuracy : 0.8482371565390674
# Training Time : 830.5742405081619

# %%
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=f['Training Time'], marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('Depth')
ax.set_ylabel('Samples')
ax.set_zlabel('Accuracy')

# legend
#plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.colorbar(sc)

# %%
points = plt.scatter(x, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(y, z,
                     c=t, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
points = plt.scatter(x, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Depth') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')

# %%
points = plt.scatter(y, t,
                     c=z, s=20, cmap=cmap)
plt.colorbar(points)
plt.xlabel('Samples') 
plt.ylabel('Training Time')
# Out:
# Text(0, 0.5, 'Training Time')
